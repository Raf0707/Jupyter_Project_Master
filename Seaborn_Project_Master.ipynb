# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StudentsPerformance.csv', sep=';')

# %%
df = df.rename(columns = {'race/ethnicity' : 'race_or_ethnicity', 'parental level of education' : 'parental_level_of_education', 'test preparation course' : 'test_preparation_course', 'math score' : 'math_score', 'reading score' : 'reading_score', 'writing score' : 'writing_score'})

# %%
df
# Out:
#      gender race_or_ethnicity parental_level_of_education         lunch  \
# 0    female           group B           bachelor's degree      standard
# 1    female           group C                some college      standard
# 2    female           group B             master's degree      standard
# 3      male           group A          associate's degree  free/reduced
# 4      male           group C                some college      standard
# 5    female           group B          associate's degree      standard
# 6    female           group B                some college      standard
# 7      male           group B                some college  free/reduced
# 8      male           group D                 high school  free/reduced
# 9    female           group B                 high school  free/reduced
# 10     male           group C          associate's degree      standard
# 11     male           group D          associate's degree      standard
# ...

# %%
df.head(8)
# Out:
#    gender race_or_ethnicity parental_level_of_education         lunch  \
# 0  female           group B           bachelor's degree      standard
# 1  female           group C                some college      standard
# 2  female           group B             master's degree      standard
# 3    male           group A          associate's degree  free/reduced
# 4    male           group C                some college      standard
# 5  female           group B          associate's degree      standard
# 6  female           group B                some college      standard
# 7    male           group B                some college  free/reduced
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      gender race_or_ethnicity parental_level_of_education         lunch  \
# 0    female           group B           bachelor's degree      standard
# 1    female           group C                some college      standard
# 2    female           group B             master's degree      standard
# 3      male           group A          associate's degree  free/reduced
# 4      male           group C                some college      standard
# 5    female           group B          associate's degree      standard
# 6    female           group B                some college      standard
# 7      male           group B                some college  free/reduced
# 8      male           group D                 high school  free/reduced
# 9    female           group B                 high school  free/reduced
# 10     male           group C          associate's degree      standard
# 11     male           group D          associate's degree      standard
# ...

# %%
df.query('math_score > 70').head(8)
# Out:
#     gender race_or_ethnicity parental_level_of_education         lunch  \
# 0   female           group B           bachelor's degree      standard
# 2   female           group B             master's degree      standard
# 4     male           group C                some college      standard
# 5   female           group B          associate's degree      standard
# 6   female           group B                some college      standard
# 13    male           group A                some college      standard
# 16    male           group C                 high school      standard
# 24    male           group D           bachelor's degree  free/reduced
#
#    test_preparation_course  math_score  reading_score  writing_score
# 0                     none          72             72             74
# 2                     none          90             95             93
# 4                     none          76             78             75
# ...

# %%
df.groupby('parental_level_of_education').head(8)
# Out:
#      gender race_or_ethnicity parental_level_of_education         lunch  \
# 0    female           group B           bachelor's degree      standard
# 1    female           group C                some college      standard
# 2    female           group B             master's degree      standard
# 3      male           group A          associate's degree  free/reduced
# 4      male           group C                some college      standard
# 5    female           group B          associate's degree      standard
# 6    female           group B                some college      standard
# 7      male           group B                some college  free/reduced
# 8      male           group D                 high school  free/reduced
# 9    female           group B                 high school  free/reduced
# 10     male           group C          associate's degree      standard
# 11     male           group D          associate's degree      standard
# ...

# %%
df.math_score.hist()

# %%
df.reading_score.hist()

# %%
df.writing_score.hist()

# %%
df.plot.scatter(x = 'math_score', y = 'reading_score')

# %%
df.plot.scatter(x = 'math_score', y = 'writing_score')

# %%
df.plot.scatter(x = 'reading_score', y = 'writing_score')

# %%
df.math_score.max()
# Out:
# 100

# %%
df.math_score.min()
# Out:
# 0

# %%
df.math_score.mean()
# Out:
# 66.089

# %%
df.reading_score.max()
# Out:
# 100

# %%
df.reading_score.min()
# Out:
# 17

# %%
df.reading_score.mean()
# Out:
# 69.169

# %%
df.writing_score.max()
# Out:
# 100

# %%
df.writing_score.min()
# Out:
# 10

# %%
df.writing_score.mean()
# Out:
# 68.054

# %%
sdf = {'gender' : ['male', 'male', 'female'], 'total_mark' : ['ok', 'good', 'bad']}

# %%
sdf = pd.DataFrame(sdf)

# %%
sdf
# Out:
#    gender total_mark
# 0    male         ok
# 1    male       good
# 2  female        bad

# %%
df.merge(sdf)
# Out:
#       gender race_or_ethnicity parental_level_of_education         lunch  \
# 0     female           group B           bachelor's degree      standard
# 1     female           group C                some college      standard
# 2     female           group B             master's degree      standard
# 3     female           group B          associate's degree      standard
# 4     female           group B                some college      standard
# 5     female           group B                 high school  free/reduced
# 6     female           group B                 high school      standard
# 7     female           group A             master's degree      standard
# 8     female           group C            some high school      standard
# 9     female           group B            some high school  free/reduced
# 10    female           group C          associate's degree  free/reduced
# 11    female           group B                some college  free/reduced
# ...

# %%
df
# Out:
#      gender race_or_ethnicity parental_level_of_education         lunch  \
# 0    female           group B           bachelor's degree      standard
# 1    female           group C                some college      standard
# 2    female           group B             master's degree      standard
# 3      male           group A          associate's degree  free/reduced
# 4      male           group C                some college      standard
# 5    female           group B          associate's degree      standard
# 6    female           group B                some college      standard
# 7      male           group B                some college  free/reduced
# 8      male           group D                 high school  free/reduced
# 9    female           group B                 high school  free/reduced
# 10     male           group C          associate's degree      standard
# 11     male           group D          associate's degree      standard
# ...

# %%
d = df.test_preparation_course

# %%
d.map('It is {}'.format)
# Out:
# 0           It is none
# 1      It is completed
# 2           It is none
# 3           It is none
# 4           It is none
# 5           It is none
# 6      It is completed
# 7           It is none
# 8      It is completed
# 9           It is none
# 10          It is none
# 11          It is none
# 12          It is none
# 13     It is completed
# 14          It is none
# 15          It is none
# 16          It is none
# 17          It is none
# 18     It is completed
# 19          It is none
# 20          It is none
# 21     It is completed
# 22          It is none
# 23          It is none
# 24     It is completed
# 25          It is none
# 26          It is none
# 27          It is none
# 28          It is none
# 29          It is none
#             ...
# 970         It is none
# 971    It is completed
# 972    It is completed
# 973         It is none
# 974         It is none
# 975    It is completed
# 976    It is completed
# 977         It is none
# 978    It is completed
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dropna().shape
# Out:
# (1000, 8)

# %%
plt.figure(figsize=(18, 8))
sns.countplot(x="male", data=df_l.merge(df_ud, how='math_score', on='reading_score').query("female == True & writing_score== 'computer'"))
plt.show()
